# %%
# from google.colab import drive
# drive.mount('/content/drive')
# data_path = '/content/drive/MyDrive/taxi_pickups_area.csv'
data_path = 'data/taxi_pickups_area.csv'

# %%
import pandas as pd
import numpy as np
import joblib

from statsmodels.tsa.seasonal import STL
from sklearn.preprocessing import MinMaxScaler
from lightgbm import LGBMRegressor
from keras.layers import LSTM, Dense
from keras.models import Sequential
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv(data_path)
df.shape
# Out:
# (8064, 79)

# %%
cols = df.columns.to_list()

time_stamp = cols[0]
df[time_stamp] = pd.to_datetime(df[time_stamp])
# df.set_index(time_stamp, inplace=True)

# %%
latest = df[time_stamp].max()

datetime_threshold = latest - pd.Timedelta(weeks=1)
datetime_threshold

train = df[df[time_stamp] < datetime_threshold]
test = df[df[time_stamp] >= datetime_threshold]

print(train.shape)
print(test.shape)
# Out:
# (7391, 79)
# (673, 79)

# %%
areas = cols[1:]
cleaned_train = train.copy()


def detect_anomalies(serie, robust=True, period=672):

    stl = STL(serie, robust=robust, period=period)

    result = stl.fit()

    resid =  result.resid

    resid_m = resid.mean()
    resid_dv = resid.std()

    lower = resid_m - (3 * resid_dv)
    upper = resid_m + (3 * resid_dv)

    return serie[(resid < lower) | (resid > upper)]


for area in areas:

    serie = cleaned_train[area].copy()

    anomalies_train = detect_anomalies(serie)

    serie.loc[anomalies_train.index] = np.nan

    serie = serie.interpolate(
        method="linear",
        limit_direction="both"
    )

    cleaned_train[area] = serie

# %%
joblib.dump(cleaned_train, 'cleaned_train.pkl')
# Out:
# ['cleaned_train.pkl']

# %%
cleaned_train = joblib.load('cleaned_train.pkl')
cols = cleaned_train.columns.to_list()
areas = cols[1:]
time_stamp = cols[0]
cleaned_train[time_stamp] = pd.to_datetime(cleaned_train[time_stamp])

# %%
def create_features_target(
    data,
    n_lags=5,
    add_lags=True,
    fill_value=0,
    slice_size=0 # to use!
):

    columns = ['area_number', 'month', 'day', 'hour', 'minute', 'demands']
    new_df = pd.DataFrame(columns=columns)

    time_features = {
        'months': [],
        'day':[],
        'hour':[],
        'minute':[]
    }

    areas_feature = []
    y = []

    for index, area in enumerate(areas):

        areas_feature.extend([index] * len(data))

        time_features['months'].extend(data[time_stamp].dt.month.to_list())
        time_features['day'].extend(data[time_stamp].dt.day.to_list())
        time_features['hour'].extend(data[time_stamp].dt.hour.to_list())
        time_features['minute'].extend(data[time_stamp].dt.minute.to_list())

        y.extend(data[area].to_list()) # target variable


    new_df['area_number'] = areas_feature
    new_df['month'] = time_features['months']
    new_df['day'] = time_features['day']
    new_df['hour'] = time_features['hour']
    new_df['minute'] = time_features['minute']
    new_df['demands'] = np.array(y)


    if add_lags:
        lag_features = {}
        for lag in range(1, n_lags + 1):
            lag_features[f'lag_{lag}'] = []

        for area in areas:

            for i, lag in enumerate(lag_features):
                lags = data[area].shift(i + 1, fill_value=fill_value)
                lag_features[lag].extend(lags.to_list())

        for lag in lag_features:
            new_df[lag] = lag_features[lag]


    return new_df

# %%
df_train = create_features_target(cleaned_train, fill_value=None)
df_test = create_features_target(test, fill_value=None)


df_train = df_train.sample(frac=1, random_state=42)
df_test = df_test.sample(frac=1, random_state=42)

df_train
# Out:
#         area_number  month  day  hour  minute  demands  lag_1  lag_2  lag_3  \
# 135613           18      4   27    19      45      0.0    0.0    0.0    0.0
# 361737           48      6   12    14      15      0.0    0.0    0.0    0.0
# 163398           22      4    9     7       0      0.0    0.0    0.0    0.0
# 346266           46      6    5    10       0      0.0    1.0    0.0    0.0
# 12389             1      5   23     1      30      3.0    1.0    2.0    4.0
# ...             ...    ...  ...   ...     ...      ...    ...    ...    ...
# 110268           14      6   10    18      30      0.0    0.0    0.0    0.0
# 259178           35      4    6     3      15      0.0    0.0    0.0    0.0
# 365838           49      5    9     7      45      0.0    0.0    0.0    0.0
# 131932           17      6    5    11      15      0.0    0.0    0.0    0.0
# 121958           16      5    9    13      30      1.0    2.0    2.0    0.0
#
#         lag_4  lag_5
# 135613    0.0    0.0
# 361737    0.0    0.0
# 163398    1.0    0.0
# 346266    1.0    0.0
# 12389     1.0    1.0
# ...       ...    ...
# 110268    0.0    0.0
# 259178    0.0    0.0
# 365838    2.0    2.0
# 131932    0.0    0.0
# 121958    4.0    2.0
#
# [576498 rows x 11 columns]

# %% [markdown]
# create lag features

# %%
X_cols = [c for c in df_train.columns if c != 'demands']

X_train = df_train[X_cols]
y_train = df_train['demands']

model = LGBMRegressor(
    n_jobs=-1,
    learning_rate=0.01,
    random_state=42
)

model.fit(
    X_train,
    y_train
)

model
# Out:
# ['area_number',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'lag_1',
#  'lag_2',
#  'lag_3',
#  'lag_4',
#  'lag_5']

# %%
joblib.dump(model, "lightgbm.pkl")
print("lightgbm model saved")
# Out:
# lightgbm model saved

# %%
#model etestuation
y_pred = model.predict(X_test)

print("MAE :", mean_absolute_error(y_test, y_pred))
# Out:
# MAE : 1.635568942675913

# %% [markdown]
# feature engineer for sequential models

# %%
def create_sequences(data: pd.Series, seq_len=96):

    X = []
    i = seq_len

    npv = data.values.copy()

    while i < len(npv):
        X.append(npv[i-seq_len : i])
        i += 1

    return X

# %%
areas_time_steps = []
for area in areas:
    areas_time_steps.extend(create_sequences(cleaned_train[area]))


areas_time_steps = np.array(areas_time_steps)
areas_time_steps.shape
# Out:
# (569010, 96)

# %%
slice_rows = 96
X_train, y_train = create_features_target(cleaned_train, add_lags=False, slice_size=slice_rows)
# X_test, y_test = create_features_target(test, add_lags=False)

print(y_train.shape)
# X_train = X_train[slice_rows:]
# y_train = y_train[slice_rows:]
# print(y_train.shape)
# X_test = X_test[slice_rows:]
# y_test = np.array(y_test)[slice_rows:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 slice_rows = 96
# ----> 2 X_train, y_train = create_features_target(cleaned_train, add_lags=False, slice_size=slice_rows)
#       3 # X_test, y_test = create_features_target(test, add_lags=False)
#       5 print(y_train.shape)
#
# Cell In[38], line 40, in create_features_target(df_, n_lags, add_lags, fill_value, slice_size)
#      35     y.extend(df_[area].to_list())
#      39 new_df['area_number'] = areas_feature
# ---> 40 new_df['month'] = time_features['months']
#      41 new_df['day'] = time_features['day']
#      42 new_df['hour'] = time_features['hour']
#
# File D:\codes\ai_ml\.venv\lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File D:\codes\ai_ml\.venv\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)
#    4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File D:\codes\ai_ml\.venv\lib\site-packages\pandas\core\frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)
#    5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File D:\codes\ai_ml\.venv\lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (576498) does not match length of index (569010)

# %%
# scaler = MinMaxScaler()
X_train.shape
# y_train = scaler.fit_transform(y_train)
# Out:
# (576402, 5)

# %%
model = Sequential([
    LSTM(64, input_shape=(96, 11)),
    Dense(1)
])

model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

model.summary()
# Out:
# D:\codes\ai_ml\.venv\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          19,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 19,521 (76.25 KB)
#  Trainable params: 19,521 (76.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(
    X,
    y,
    epochs=10,
    batch_size=256
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 model.fit(
#       2     X,
#       3     y,
#       4     epochs=10,
#       5     batch_size=256
#       6 )
#
# File D:\codes\ai_ml\.venv\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File D:\codes\ai_ml\.venv\lib\site-packages\keras\src\trainers\data_adapters\__init__.py:163, in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     155     return GeneratorDataAdapter(x)
#     156     # TODO: should we warn or not?
#     157     # warnings.warn(
#     158     #     "`shuffle=True` was passed, but will be ignored since the "
#    (...)
#     161     # )
#     162 else:
# --> 163     raise ValueError(f"Unrecognized data type: x={x} (of type {type(x)})")
#
# ValueError: Unrecognized data type: x=[[[ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   ...
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]]
#
#  [[ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   ...
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]]
#
#  [[ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   ...
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]
#   [ 0.  0.  4. ...  0.  0.  0.]]
#
#  ...
#
#  [[ 1. 77.  6. ...  0.  0.  1.]
#   [ 0. 77.  6. ...  0.  0.  1.]
#   [ 3. 77.  6. ...  0.  0.  1.]
#   ...
#   [ 0. 77.  6. ...  0.  0.  1.]
#   [ 0. 77.  6. ...  0.  0.  1.]
#   [ 0. 77.  6. ...  0.  0.  1.]]
#
#  [[ 0. 77.  6. ...  0.  0.  0.]
#   [ 3. 77.  6. ...  0.  0.  0.]
#   [ 1. 77.  6. ...  0.  0.  0.]
#   ...
#   [ 0. 77.  6. ...  0.  0.  0.]
#   [ 0. 77.  6. ...  0.  0.  0.]
#   [ 0. 77.  6. ...  0.  0.  0.]]
#
#  [[ 3. 77.  6. ...  0.  0.  0.]
#   [ 1. 77.  6. ...  0.  0.  0.]
#   [ 0. 77.  6. ...  0.  0.  0.]
#   ...
#   [ 0. 77.  6. ...  0.  0.  0.]
#   [ 0. 77.  6. ...  0.  0.  0.]
#   [ 1. 77.  6. ...  0.  0.  0.]]] (of type <class 'numpy.ndarray'>)
